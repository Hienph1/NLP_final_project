# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\phamh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
_stopwords = stopwords.words('english')

# %%
custom_stopwords = open('stop_words.txt').read().splitlines()

# %%
custom_stopwords
# Out:
# ['ai ai',
#  'ai nấy',
#  'ai đó',
#  'alô',
#  'anh',
#  'anh ấy',
#  'ba',
#  'ba ba',
#  'ba bản',
#  'ba cùng',
#  'ba họ',
#  'ba ngày',
#  'ba ngôi',
#  'ba tăng',
#  'bao giờ',
#  'bao lâu',
#  'bao nhiêu',
#  'bao nả',
#  'bay biến',
#  'biết',
#  'biết bao',
#  'biết bao nhiêu',
#  'biết chắc',
#  'biết chừng nào',
#  'biết mình',
#  'biết mấy',
#  'biết thế',
#  'biết trước',
#  'biết việc',
#  'biết đâu',
#  'biết đâu chừng',
#  'biết đâu đấy',
#  'biết được',
#  'buổi',
#  'buổi làm',
#  'buổi mới',
#  'buổi ngày',
#  'buổi sớm',
#  'bà',
#  'bà ấy',
#  'bài',
#  'bài bác',
#  'bài bỏ',
#  'bài cái',
#  'bác',
#  'bán',
#  'bán cấp',
#  'bán dạ',
#  'bán thế',
#  'bây bẩy',
#  'bây chừ',
#  'bây giờ',
#  'bây nhiêu',
#  'bèn',
#  'béng',
#  'bên',
#  'bên bị',
#  'bên có',
#  'bên cạnh',
#  'bông',
#  'bước',
#  'bước khỏi',
#  'bước tới',
#  'bước đi',
#  'bạn',
#  'bản',
#  'bản bộ',
#  'bản riêng',
#  'bản thân',
#  'bản ý',
#  'bất chợt',
#  'bất cứ',
#  'bất giác',
# ...

# %%
_stopwords = _stopwords + custom_stopwords

# %%
import pandas as pd
 
# read by default 1st sheet of an excel file
dataframe1 = pd.read_excel('Table1.xlsx')
 
print(dataframe1)
# Out:
#           Loai thuoc                                                Ten  \
# 0   thuoc khang sinh                                           Auclatyl
# 1                NaN                                          Klamentin
# 2                NaN  TV.Cefuroxime 500mg trị nhiễm khuẩn (3 vỉ x 10...
# 3                NaN       Augmentin 1g trị nhiễm khuẩn (2 vỉ x 7 viên)
# 4                NaN  Dorogyne trị nhiễm khuẩn răng miệng (2 vỉ x 10...
# 5                NaN     Ospamox 500mg trị nhiễm khuẩn (1 vỉ x 10 viên)
# 6                NaN  Ampicillin Domesco 500mg trị nhiễm khuẩn (10 v...
# 7                NaN  Novofungin 250 phòng, trị nhiễm khuẩn kỵ khí (...
# 8                NaN  Amoxicillin Domesco 500mg trị nhiễm khuẩn (10 ...
# 9                NaN   Wonfixime 200mg trị nhiễm khuẩn (1 vỉ x 10 viên)
# 10               NaN    Fonroxil 500mg trị nhiễm khuẩn (3 vỉ x 10 viên)
# 11               NaN  Glogyl trị nhiễm khuẩn răng miệng cấp tính, mạ...
# ...

# %%
dataframe1.iloc[2][2]
# Out:
# 'Hoạt chất: Cefuroxim (dạng Cefuroxim axetil) 500mg.\nTá dược: Titan oxyd, avicel, aerosil 200, disolcel, natri laurylsulfat, HPMC, isopropanol, DST, magnesium stearat, PEG 6000, Talc vừa đủ 1 viên.'

# %%
from underthesea import sent_tokenize

# %%
# Breaking text into individual sentences
text = dataframe1.iloc[2][2]
sentences = sent_tokenize(text)

# %%
print(sentences)
# Out:
# ['Hoạt chất: Cefuroxim (dạng Cefuroxim axetil) 500mg.', 'Tá dược: Titan oxyd, avicel, aerosil 200, disolcel, natri laurylsulfat, HPMC, isopropanol, DST, magnesium stearat, PEG 6000, Talc vừa đủ 1 viên.']

# %%
from underthesea import word_tokenize

# %%
# Deviding text into individual words
words = word_tokenize(text)
print(words)
# Out:
# ['Hoạt chất', ':', 'Cefuroxim', '(', 'dạng', 'Cefuroxim axetil', ')', '500', 'mg', '.', 'Tá dược', ':', 'Titan oxyd', ',', 'avicel', ',', 'aerosil', '200', ',', 'disolcel', ',', 'natri', 'laurylsulfat', ',', 'HPMC', ',', 'isopropanol', ',', 'DST', ',', 'magnesium', 'stearat', ',', 'PEG', '6000', ',', 'Talc', 'vừa', 'đủ', '1', 'viên', '.']

# %%
import string
stop = _stopwords + list(string.punctuation)
stop
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
utt_nosw = [w for w in words if not w in stop]

# %%
'bằng' in stop
# Out:
# True

# %%
utt_nosw
# Out:
# ['Hoạt chất',
#  'Cefuroxim',
#  'dạng',
#  'Cefuroxim axetil',
#  '500',
#  'mg',
#  'Tá dược',
#  'Titan oxyd',
#  'avicel',
#  'aerosil',
#  '200',
#  'disolcel',
#  'natri',
#  'laurylsulfat',
#  'HPMC',
#  'isopropanol',
#  'DST',
#  'magnesium',
#  'stearat',
#  'PEG',
#  '6000',
#  'Talc',
#  '1']

# %%
utt_nosw = [i for i in utt_nosw if not i.isdigit()]

# %%
utt_nosw
# Out:
# ['Hoạt chất',
#  'Cefuroxim',
#  'dạng',
#  'Cefuroxim axetil',
#  'mg',
#  'Tá dược',
#  'Titan oxyd',
#  'avicel',
#  'aerosil',
#  'disolcel',
#  'natri',
#  'laurylsulfat',
#  'HPMC',
#  'isopropanol',
#  'DST',
#  'magnesium',
#  'stearat',
#  'PEG',
#  'Talc']
